# %%
import pickle
import json
import pandas as pd
import numpy as np

# %%
with open('linear_regression.pkl',"rb")as f:
    lin_reg_model= pickle.load(f)

# %%
label_enc_data = {"smoker" : {'no': 0, 'yes': 1},
                "gender" : {'male':1, 'female':0}}

with open('label_enc_data.json', 'w') as f:
    json.dump(label_enc_data,f)

# %%
lin_reg_model
# Out:
# LinearRegression()

# %%
label_enc_data
# Out:
# {'smoker': {'no': 0, 'yes': 1}, 'gender': {'male': 1, 'female': 0}}

# %%
column_names = lin_reg_model.feature_names_in_

# %%
print(column_names)
# Out:
# ['age' 'gender' 'bmi' 'children' 'smoker' 'region_northeast'
#  'region_northwest' 'region_southeast' 'region_southwest']

# %%
len(column_names)
# Out:
# 9

# %%
age = 24
gender = 'female'
bmi = 27.8
children = 2
smoker = 'yes'
region = 'southeast'

# %%
region = 'region_'+region
region
# Out:
# 'region_southeast'

# %%
print(column_names)
# Out:
# ['age' 'gender' 'bmi' 'children' 'smoker' 'region_northeast'
#  'region_northwest' 'region_southeast' 'region_southwest']

# %%
test_array = np.zeros((1, len(column_names)))

test_array[0,0] = age
test_array[0,1] = label_enc_data['gender'][gender]
test_array[0,2] = bmi
test_array[0,3] = children
test_array[0,4] = label_enc_data['smoker'][smoker]
region = 'southeast'
region = f"region_{region}"   

region_index = list(column_names).index(region)
test_array[0,region_index]=1
test_array
# Out:
# array([[24. ,  0. , 27.8,  2. ,  1. ,  0. ,  0. ,  1. ,  0. ]])

# %%
prediction = lin_reg_model.predict(test_array)[0]
print('Predicted Price is:',np.around(prediction,3))
# Out:
# Predicted Price is: 27166.063
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
